# %%
import pandas as pd

# Define the URL of the Apple annual report webpage
url = "https://d18rn0p25nwr6d.cloudfront.net/CIK-0000320193/183e85fb-71d2-4b0e-8cbb-f1e5fbaeca04.html"

# Use pandas read_html() to extract the table from the HTML content
tables = pd.read_html(url)
data_table = tables[0]  # the first table contains the financial data

# Display the extracted data table
print(data_table)
# Out:
#    Cover Page - USD ($)  shares in Thousands, $ in Millions  \
#    Cover Page - USD ($)  shares in Thousands, $ in Millions
# 0                     Entity Information [Line Items]
# 1                                       Document Type
# 2                              Document Annual Report
# 3                        Current Fiscal Year End Date
# 4                            Document Period End Date
# ..                                                ...
# 81                              3.600% Notes due 2042
# 82                    Entity Information [Line Items]
# 83                            Title of 12(b) Security
# 84                             No Trading Symbol Flag
# 85                             Security Exchange Name
#
#           12 Months Ended Unnamed: 2_level_0 Unnamed: 3_level_0
#             Sep. 24, 2022      Oct. 14, 2022      Mar. 25, 2022
# 0                     NaN                NaN                NaN
# ...

# %%
tables
# Out:
# [   Cover Page - USD ($)  shares in Thousands, $ in Millions  \
#     Cover Page - USD ($)  shares in Thousands, $ in Millions
#  0                     Entity Information [Line Items]
#  1                                       Document Type
#  2                              Document Annual Report
#  3                        Current Fiscal Year End Date
#  4                            Document Period End Date
#  ..                                                ...
#  81                              3.600% Notes due 2042
#  82                    Entity Information [Line Items]
#  83                            Title of 12(b) Security
#  84                             No Trading Symbol Flag
#  85                             Security Exchange Name
#
#            12 Months Ended Unnamed: 2_level_0 Unnamed: 3_level_0
#              Sep. 24, 2022      Oct. 14, 2022      Mar. 25, 2022
#  0                     NaN                NaN                NaN
# ...

# %%
file = "/Users/P2982820/Downloads/finance/Data Scrapping/Apple.pdf"

# %%
import pandas as pd
import tabula

# Define the path to the PDF file
pdf_path = file

# Use tabula to extract the tables from the PDF file
tables = tabula.read_pdf
tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# Convert the tables to pandas DataFrames
dfs = [pd.DataFrame(table) for table in tables]

# Print the first 5 rows of each DataFrame
for i, df in enumerate(dfs):
    print(f"Table {i}:")
    print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 8
#       5 pdf_path = file
#       7 # Use tabula to extract the tables from the PDF file
# ----> 8 tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)
#      10 # Convert the tables to pandas DataFrames
#      11 dfs = [pd.DataFrame(table) for table in tables]
#
# AttributeError: module 'tabula' has no attribute 'read_pdf'
